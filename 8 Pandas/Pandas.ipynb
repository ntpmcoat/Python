# %% [markdown]
#
#                                                 Basics

# %%
import  pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# =>it reads only structured data

# %%
# by default pandas considers first row as column name to stop this we use header = none
df = pd.read_csv("NBA_data.csv")

# %%
# returns first five records or  x records from top---------------df.head(x)
df.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
# returns last five records or  x records from bottom---------------df.tail(x)
df.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# returns column names
df.columns

list(df.columns)
# Out:
# ['Rk',
#  'Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'eFG%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %%
# to get data of particular columns 
# df[--col name---]

# type(df[--x--])==========>'series'(shows indx) which is same as list(doesn't shows indx)
# when we reteive any single row or column it returns series

# %%
# if we pass col name as list then it will be considered as series 
# type(df[[--x--]])

# %%
# whenwe want to  retrive multiple col we pass names as list 
# df[[--x--,--x--,--x--]]

# %%
# returns the col names and data types of columns understood by pandas like(int float object[string] etc)
df.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
# to read excel sheet , we can secify which sheet to read 
df1 =pd.read_excel(" ")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 # to read excel sheet , we can secify which sheet to read
# ----> 2 df1 =pd.read_excel(" ")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
# rest methods are same

# %%
# can also read from link
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
pip install lxml

# %%
import pandas as pd 
# import lxml

# %%
# read data from html page 
# ---reads only tabular data 
# ----will all the tables present on site separately
url_data=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df3 = url_data[0]

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df3.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df3.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df3.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df3.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df3[['Rk', 'Player', 'Pos', 'Age']]
# Out:
#       Rk          Player Pos Age
# 0      1      Quincy Acy  PF  24
# 1      2    Jordan Adams  SG  20
# 2      3    Steven Adams   C  21
# 3      4     Jeff Adrien  PF  28
# 4      5   Arron Afflalo  SG  29
# ..   ...             ...  ..  ..
# 670  490  Thaddeus Young  PF  26
# 671  490  Thaddeus Young  PF  26
# 672  490  Thaddeus Young  PF  26
# 673  491     Cody Zeller   C  22
# 674  492    Tyler Zeller   C  25
#
# [675 rows x 4 columns]

# %%
# to store data permanantly in any format
# df3.to_csv("NBA_data.csv")---------stores index too by default to ignore this 
df3.to_csv("NBA_data.csv", index= False)

# %% [markdown]
#                                         Advance

# %%
import pandas as pd
f = pd.read_csv("titanic.csv")

# %%
f.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# type(f)
f.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# provides statistical data of "numeric" colmns only
f.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
# manually
f[["Name", "Sex","Ticket","Cabin", "Embarked"]]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
f.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
# returns series to get only col name we take index from this
x = f.dtypes[f.dtypes == "object"].index

# %%
f[x].describe()
# Out:
#                            Name   Sex Ticket        Cabin Embarked
# count                       156   156    156           31      155
# unique                      156     2    145           28        3
# top     Braund, Mr. Owen Harris  male   2651  C23 C25 C27        S
# freq                          1   100      2            2      110

# %%
# to get data of type float

f[f.dtypes[f.dtypes =="float"].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 151  22.0  66.6000
# 152  55.5   8.0500
# 153  40.5  14.5000
# 154   NaN   7.3125
# 155  51.0  61.3792
#
# [156 rows x 2 columns]

# %%
f[f.dtypes[f.dtypes =="int64"].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 151          152         1       1      1      0
# 152          153         0       3      0      0
# 153          154         0       3      0      2
# 154          155         0       3      0      0
# 155          156         0       1      0      1
#
# [156 rows x 5 columns]

# %%
# to get data from random part
f[["Ticket"]][4:11:]
# Out:
#      Ticket
# 4    373450
# 5    330877
# 6     17463
# 7    349909
# 8    347742
# 9    237736
# 10  PP 9549

# %%
# to add a new data in dataframe
f['sr']=0

# %%
f
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# to crate a new col by some operations on exisiting cols
f['Age+Pclass']= f['Pclass']+ f['Age']

# %%
f
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# to get all unique values in any particular columns
pd.Categorical(f["Pclass"])
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(f["Pclass"]).unique()
# Out:
# [3, 1, 2]
# Categories (3, int64): [1, 2, 3]

# %%
(f["Cabin"]).unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2'], dtype=object)

# %%
# to filter
f[f['Age']<18]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 9             10         1       2       Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 14            15         0       3      Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                      Rice, Master. Eugene
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 39            40         1       3               Nicola-Yarred, Miss. Jamila
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 50            51         0       3                Panula, Master. Juha Niilo
# 58            59         1       2              West, Miss. Constance Mirium
# ...

# %%
f[f['Fare']>32.20]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 35            36         0       1
# 43            44         1       2
# 50            51         0       3
# 52            53         1       1
# 54            55         0       1
# 55            56         1       1
# 59            60         0       3
# 61            62         1       1
# 62            63         0       1
# 71            72         0       3
# 72            73         0       2
# 74            75         1       3
# 83            84         0       1
# 86            87         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# ...

# %%
f[f['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 0              1         0       3          Braund, Mr. Owen Harris  male
# 4              5         0       3         Allen, Mr. William Henry  male
# 5              6         0       3                 Moran, Mr. James  male
# 6              7         0       1          McCarthy, Mr. Timothy J  male
# 7              8         0       3   Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                              ...   ...
# 150          151         0       2       Bateman, Rev. Robert James  male
# 152          153         0       3                 Meo, Mr. Alfonzo  male
# 153          154         0       3  van Billiard, Mr. Austin Blyler  male
# 154          155         0       3            Olsen, Mr. Ole Martin  male
# 155          156         0       1      Williams, Mr. Charles Duane  male
#
#       Age  SibSp  Parch       Ticket     Fare Cabin Embarked  sr  Age+Pclass
# ...

# %%
#---------find a female passenger whose age is greater than 60
f[(f['Sex']=="male") & (f["Age"]>60)]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 96            97         0       1       Goldschmidt, Mr. George B  male
# 116          117         0       3            Connors, Mr. Patrick  male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked  sr  Age+Pclass
# 33   66.0      0      0  C.A. 24579  10.5000   NaN        S   0        68.0
# 54   65.0      0      1      113509  61.9792   B30        C   0        66.0
# 96   71.0      0      0    PC 17754  34.6542    A5        C   0        72.0
# 116  70.5      0      0      370369   7.7500   NaN        Q   0        73.5

# %%
# ----------to get passenger who paid max fare

f[f["Fare"] ==max(f["Fare"])]['Name']
# Out:
# 27    Fortune, Mr. Charles Alexander
# 88        Fortune, Miss. Mabel Helen
# Name: Name, dtype: object

# %%
f.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  sr  Age+Pclass
# 0      0         A/5 21171   7.2500   NaN        S   0        25.0
# 1      0          PC 17599  71.2833   C85        C   0        39.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S   0        29.0
# ...

# %%
# to find any random data matrix search types
f[['PassengerId','Survived','Pclass']][2:5]
# Out:
#    PassengerId  Survived  Pclass
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
# iloc and loc
#  iloc--->uses in-built index for cols i.e 0,1,2,3,.........
# f.iloc[row,col]
# row/col ---------- can be list or slice 

f.iloc[0:2,[1,2]]
# Out:
#    Survived  Pclass
# 0         0       3
# 1         1       1

# %%
f.iloc[[1,4],0:2]
# Out:
#    PassengerId  Survived
# 1            2         1
# 4            5         0

# %%
f.loc[0:2,["PassengerId", "Age"]]
# Out:
#    PassengerId   Age
# 0            1  22.0
# 1            2  38.0
# 2            3  26.0

# %% [markdown]
#                         Part 3

# %%
import pandas as pd
df = pd.read_csv("titanic.csv")

# %%
# pandas provides freedom to change index
#  but python remebers original index I.e we are able to change index externally not internally
# can call by default or user-defined index


x =df['Name'][0:5]
x
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
ls=['a','b','c','d','e']

pd.Series(x,index=ls)
# Out:
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# Name: Name, dtype: object

# %%
y= pd.Series(list(x),index=ls)

# %%
y
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# dtype: object

# %%
# Arithmetic operation  based on index
x*y
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# dtype: object

# %% [markdown]
#                                                     Part 4

# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# to delete column or row 
# doesn't delets permanantly original is not affected


df.drop("PassengerId", axis=1)   # row--->axis=0(default)     column ----> axis=1
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 151         1       1                  Pears, Mrs. Thomas (Edith Wearne)
# 152         0       3                                   Meo, Mr. Alfonzo
# 153         0       3                    van Billiard, Mr. Austin Blyler
# 154         0       3                              Olsen, Mr. Ole Martin
# 155         0       1                        Williams, Mr. Charles Duane
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# for permanently changes reassign or make inplace=true  false(default)
df.drop("PassengerId", axis=1, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 151         1       1                  Pears, Mrs. Thomas (Edith Wearne)
# 152         0       3                                   Meo, Mr. Alfonzo
# 153         0       3                    van Billiard, Mr. Austin Blyler
# 154         0       3                              Olsen, Mr. Ole Martin
# 155         0       1                        Williams, Mr. Charles Duane
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# for any row 
df.drop(155,inplace=True) # axis by default =0

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 150         0       2                         Bateman, Rev. Robert James
# 151         1       1                  Pears, Mrs. Thomas (Edith Wearne)
# 152         0       3                                   Meo, Mr. Alfonzo
# 153         0       3                    van Billiard, Mr. Austin Blyler
# 154         0       3                              Olsen, Mr. Ole Martin
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# To make any existing column as index  but not permanantly
df.set_index("Name")
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# ...                                                      ...     ...     ...
# Bateman, Rev. Robert James                                 0       2    male
# Pears, Mrs. Thomas (Edith Wearne)                          1       1  female
# Meo, Mr. Alfonzo                                           0       3    male
# van Billiard, Mr. Austin Blyler                            0       3    male
# Olsen, Mr. Ole Martin                                      0       3    male
#
# ...

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
# permanant changes 
df.set_index("Name" , inplace=True)
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0      1      0
# Allen, Mr. William Henry                            35.0      0      0
#
# ...

# %%
# to get default index back we use
df.reset_index(inplace=True)

# %%
# to make a dictinarty as dataframe where key is  col and it values are its rows
d={
    "odd":[1,3,5,7,9],
    "even":[2,4,6,8,10]
}

pd.DataFrame(d)
# Out:
#    odd  even
# 0    1     2
# 1    3     4
# 2    5     6
# 3    7     8
# 4    9    10

# %%
# deletes row which has any val === NaN   for permanant inplace = True
# default axis =0
df.dropna()
# Out:
#                                                   Name  Survived  Pclass  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 6                              McCarthy, Mr. Timothy J         0       1
# 10                     Sandstrom, Miss. Marguerite Rut         1       3
# 11                            Bonnell, Miss. Elizabeth         1       1
# 21                               Beesley, Mr. Lawrence         1       2
# 23                        Sloper, Mr. William Thompson         1       1
# 27                      Fortune, Mr. Charles Alexander         0       1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)         1       1
# 54                      Ostby, Mr. Engelhart Cornelius         0       1
# 62                         Harris, Mr. Henry Birkhardt         0       1
# 66                        Nye, Mrs. (Elizabeth Ramell)         1       2
# ...

# %%
df.dropna(axis=1)
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 150                         Bateman, Rev. Robert James         0       2
# 151                  Pears, Mrs. Thomas (Edith Wearne)         1       1
# 152                                   Meo, Mr. Alfonzo         0       3
# 153                    van Billiard, Mr. Austin Blyler         0       3
# 154                              Olsen, Mr. Ole Martin         0       3
#
#         Sex  SibSp  Parch            Ticket     Fare
# ...

# %%
# to fill null values -----for parmanant inplca
df.fillna("@@@@@@@@")
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 150                         Bateman, Rev. Robert James         0       2
# 151                  Pears, Mrs. Thomas (Edith Wearne)         1       1
# 152                                   Meo, Mr. Alfonzo         0       3
# 153                    van Billiard, Mr. Austin Blyler         0       3
# 154                              Olsen, Mr. Ole Martin         0       3
#
#         Sex       Age  SibSp  Parch            Ticket     Fare     Cabin  \
# ...

# %%
x =df.groupby('Sex')

# %%
x.sum()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_5620\2925620302.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   x.sum()
#         Survived  Pclass      Age  SibSp  Parch       Fare
# Sex
# female        40     138  1150.00     49     29  1593.7958
# male          14     239  2344.83     47     32  2729.9206

# %%
x.mean()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_5620\3791599204.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   x.mean()
#         Survived    Pclass        Age     SibSp     Parch       Fare
# Sex
# female  0.714286  2.464286  24.468085  0.875000  0.517857  28.460639
# male    0.141414  2.414141  30.061923  0.474747  0.323232  27.574956

# %%
# to make rows col and col as row I.e transpose 

x.max().transpose()
# x.max().T
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_5620\2556355411.py:3: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   x.max().transpose()
# Sex                     female                             male
# Name      Zabour, Miss. Hileni  van Billiard, Mr. Austin Blyler
# Survived                     1                                1
# Pclass                       3                                3
# Age                       58.0                             71.0
# SibSp                        5                                5
# Parch                        5                                5
# Ticket              W./C. 6608                      W.E.P. 5734
# Fare                     263.0                            263.0

# %%
# lets take 2 subsets of datafame
df1= df[["Name", "Survived", "Pclass"]][0:5]
df2= df[["Name", "Survived", "Pclass"]][10:15]

# %%
df1
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3

# %%
df2
# Out:
#                                     Name  Survived  Pclass
# 10       Sandstrom, Miss. Marguerite Rut         1       3
# 11              Bonnell, Miss. Elizabeth         1       1
# 12        Saundercock, Mr. William Henry         0       3
# 13           Andersson, Mr. Anders Johan         0       3
# 14  Vestrom, Miss. Hulda Amanda Adolfina         0       3

# %%
# in pandas we can merge two dataframe either horizontaly or vertically 

pd.concat([df1,df2])
# Out:
#                                                  Name  Survived  Pclass
# 0                             Braund, Mr. Owen Harris         0       3
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                              Heikkinen, Miss. Laina         1       3
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                            Allen, Mr. William Henry         0       3
# 10                    Sandstrom, Miss. Marguerite Rut         1       3
# 11                           Bonnell, Miss. Elizabeth         1       1
# 12                     Saundercock, Mr. William Henry         0       3
# 13                        Andersson, Mr. Anders Johan         0       3
# 14               Vestrom, Miss. Hulda Amanda Adolfina         0       3

# %%
pd.concat([df1,df2] , axis =1)
# Out:
#                                                  Name  Survived  Pclass  \
# 0                             Braund, Mr. Owen Harris       0.0     3.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 2                              Heikkinen, Miss. Laina       1.0     3.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)       1.0     1.0
# 4                            Allen, Mr. William Henry       0.0     3.0
# 10                                                NaN       NaN     NaN
# 11                                                NaN       NaN     NaN
# 12                                                NaN       NaN     NaN
# 13                                                NaN       NaN     NaN
# 14                                                NaN       NaN     NaN
#
#                                     Name  Survived  Pclass
# 0                                    NaN       NaN     NaN
# ...

# %%
d1 = pd.DataFrame({
    "one":[1,2,3,4,5],
    "Two":[2,4,6,8,10],
})

d2= pd.DataFrame({
    "one":[1,3,4,5],
    "Three":[3,9,12,15],
})

# %%
d1
# Out:
#    one  Two
# 0    1    2
# 1    2    4
# 2    3    6
# 3    4    8
# 4    5   10

# %%
d2
# Out:
#    one  Three
# 0    1      3
# 1    3      9
# 2    4     12
# 3    5     15

# %%
# merge-----------return data common to both based on ny key
# it is same as 'joins' in sql
# by default how='inner'
pd.merge(d1,d2)
# Out:
#    one  Two  Three
# 0    1    2      3
# 1    3    6      9
# 2    4    8     12
# 3    5   10     15

# %%
pd.merge(d1,d2,how='left')
# Out:
#    one  Two  Three
# 0    1    2    3.0
# 1    2    4    NaN
# 2    3    6    9.0
# 3    4    8   12.0
# 4    5   10   15.0

# %%
pd.merge(d1,d2,how="right")
# Out:
#    one  Two  Three
# 0    1    2      3
# 1    3    6      9
# 2    4    8     12
# 3    5   10     15

# %%
pd.merge(d1,d2, how="outer")
# Out:
#    one  Two  Three
# 0    1    2    3.0
# 1    2    4    NaN
# 2    3    6    9.0
# 3    4    8   12.0
# 4    5   10   15.0

# %%
pd.merge(d1,d2, how="cross")
# Out:
#     one_x  Two  one_y  Three
# 0       1    2      1      3
# 1       1    2      3      9
# 2       1    2      4     12
# 3       1    2      5     15
# 4       2    4      1      3
# 5       2    4      3      9
# 6       2    4      4     12
# 7       2    4      5     15
# 8       3    6      1      3
# 9       3    6      3      9
# 10      3    6      4     12
# 11      3    6      5     15
# 12      4    8      1      3
# 13      4    8      3      9
# 14      4    8      4     12
# 15      4    8      5     15
# 16      5   10      1      3
# 17      5   10      3      9
# 18      5   10      4     12
# 19      5   10      5     15

# %%
# can set index while creating dataframe
f1= pd.DataFrame({
    "A":[1,2,3,4,5],
    "B":[2,4,6,8,10],
},index=["a","b","c","d","e"])
f2= pd.DataFrame({
    "C":[1,2,3,4,5],
    "D":[12,14,16,18,20],
},index=["a","b","h","g","j"])

# %%
f1
# Out:
#    A   B
# a  1   2
# b  2   4
# c  3   6
# d  4   8
# e  5  10

# %%
f2
# Out:
#    C   D
# a  1  12
# b  2  14
# h  3  16
# g  4  18
# j  5  20

# %%
# difference b/w merge and join is merge works on colum
#  joins works on index


# default left
f1.join(f2)
# Out:
#    A   B    C     D
# a  1   2  1.0  12.0
# b  2   4  2.0  14.0
# c  3   6  NaN   NaN
# d  4   8  NaN   NaN
# e  5  10  NaN   NaN

# %%
f1.join(f2,how='right')
# Out:
#      A    B  C   D
# a  1.0  2.0  1  12
# b  2.0  4.0  2  14
# h  NaN  NaN  3  16
# g  NaN  NaN  4  18
# j  NaN  NaN  5  20

# %%
f1.join(f2,how='inner')
# Out:
#    A  B  C   D
# a  1  2  1  12
# b  2  4  2  14

# %%
f1.join(f2,how='outer')
# Out:
#      A     B    C     D
# a  1.0   2.0  1.0  12.0
# b  2.0   4.0  2.0  14.0
# c  3.0   6.0  NaN   NaN
# d  4.0   8.0  NaN   NaN
# e  5.0  10.0  NaN   NaN
# g  NaN   NaN  4.0  18.0
# h  NaN   NaN  3.0  16.0
# j  NaN   NaN  5.0  20.0

# %%
f1.join(f2,how='cross')
# Out:
#     A   B  C   D
# 0   1   2  1  12
# 1   1   2  2  14
# 2   1   2  3  16
# 3   1   2  4  18
# 4   1   2  5  20
# 5   2   4  1  12
# 6   2   4  2  14
# 7   2   4  3  16
# 8   2   4  4  18
# 9   2   4  5  20
# 10  3   6  1  12
# 11  3   6  2  14
# 12  3   6  3  16
# 13  3   6  4  18
# 14  3   6  5  20
# 15  4   8  1  12
# 16  4   8  2  14
# 17  4   8  3  16
# 18  4   8  4  18
# 19  4   8  5  20
# 20  5  10  1  12
# 21  5  10  2  14
# 22  5  10  3  16
# 23  5  10  4  18
# 24  5  10  5  20

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 150                         Bateman, Rev. Robert James         0       2
# 151                  Pears, Mrs. Thomas (Edith Wearne)         1       1
# 152                                   Meo, Mr. Alfonzo         0       3
# 153                    van Billiard, Mr. Austin Blyler         0       3
# 154                              Olsen, Mr. Ole Martin         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# function like map that based on sum formula to update all the values




# Q to make new col and find fare in inr
df["Fare INR"]= df['Fare'].apply(lambda x : x*82.20)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#      Fare INR
# 0   595.95000
# 1  5859.48726
# 2   651.43500
# 3  4364.82000
# 4   661.71000

# %%
# Q  find length of name
df["name len"]= df['Name'].apply(lambda x : len(x))

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 150                         Bateman, Rev. Robert James         0       2
# 151                  Pears, Mrs. Thomas (Edith Wearne)         1       1
# 152                                   Meo, Mr. Alfonzo         0       3
# 153                    van Billiard, Mr. Austin Blyler         0       3
# 154                              Olsen, Mr. Ole Martin         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
# Q divide data in different category based on fare { less than 10 : cheap, 

def cat(x): 
    if x<10 :
        return "Cheap"
    elif x<=10 and x<20:
        return "Moderate"
    else :
        return "High"
    
df["Cat_fare"]= df['Fare'].apply(cat)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 150                         Bateman, Rev. Robert James         0       2
# 151                  Pears, Mrs. Thomas (Edith Wearne)         1       1
# 152                                   Meo, Mr. Alfonzo         0       3
# 153                    van Billiard, Mr. Austin Blyler         0       3
# 154                              Olsen, Mr. Ole Martin         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %% [markdown]
#                                                 Part 5

# %%
import pandas as pd

# %%
data ={
    "a" :[1,2,3,4],
    "b":[4,5,6,7],
    "c":["Nikhil","ram","Shiv","Rudra"]
}

df=pd.DataFrame(data,index=["a",'b','c','d'])

# %%
df
# Out:
#    a  b       c
# a  1  4  Nikhil
# b  2  5     ram
# c  3  6    Shiv
# d  4  7   Rudra

# %%
# reindexing---->order ----in sense sort based on random list
df.reindex(['b','c','a','d'])
# Out:
#    a  b       c
# b  2  5     ram
# c  3  6    Shiv
# a  1  4  Nikhil
# d  4  7   Rudra

# %%
df
# Out:
#    a  b       c
# a  1  4  Nikhil
# b  2  5     ram
# c  3  6    Shiv
# d  4  7   Rudra

# %%
# print row wies
for i,j in df.iterrows():
    print("====",i,"=====")
    print(j)
# Out:
# ==== a =====
# a         1
# b         4
# c    Nikhil
# Name: a, dtype: object
# ==== b =====
# a      2
# b      5
# c    ram
# Name: b, dtype: object
# ==== c =====
# a       3
# b       6
# c    Shiv
# Name: c, dtype: object
# ==== d =====
# a        4
# b        7
# c    Rudra
# Name: d, dtype: object

# %%
# prints colwise
for i,j in df.iteritems():
    print("====",i,"=====")
    print(j)
# Out:
# ==== a =====
# a    1
# b    2
# c    3
# d    4
# Name: a, dtype: int64
# ==== b =====
# a    4
# b    5
# c    6
# d    7
# Name: b, dtype: int64
# ==== c =====
# a    Nikhil
# b       ram
# c      Shiv
# d     Rudra
# Name: c, dtype: object
# C:\Users\asus\AppData\Local\Temp\ipykernel_10836\387451143.py:2: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i,j in df.iteritems():

# %%
# to find summation col wise----------------- default axis =0
df.apply(lambda x: x.sum())
# Out:
# a                    10
# b                    22
# c    NikhilramShivRudra
# dtype: object

# %%
df1=df[["a","b"]]

# %%
df1
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6
# d  4  7

# %%
# Q   find sq of all ele

# df1.apply(lambda x: x**2)
df1.applymap(lambda x: x**2)
# Out:
#     a   b
# a   1  16
# b   4  25
# c   9  36
# d  16  49

# %%
# Sort based on any col
# can give multiple col
# can choose asec/desc
df.sort_values("c")
# Out:
#    a  b       c
# a  1  4  Nikhil
# d  4  7   Rudra
# c  3  6    Shiv
# b  2  5     ram

# %%
df.sort_index(ascending=False)
# Out:
#    a  b       c
# d  4  7   Rudra
# c  3  6    Shiv
# b  2  5     ram
# a  1  4  Nikhil

# %% [markdown]
# =>sometime there may be huge data at any point which normally not displayed
# =>to overcome this we set the width of col

# %%
pd.set_option("display.max_colwidth",200)
df3=pd.DataFrame({"des" :["sometime there may be huge data at any point which normally not displayed to overcome this we set the width of col"] })
df3
# Out:
#                                                                                                                   des
# 0  sometime there may be huge data at any point which normally not displayed to overcome this we set the width of col

# %% [markdown]
#     Window function
#
#
# =>take current value and n previous values and performs operation

# %%
df4=pd.DataFrame({'a':[2,4,6,8]})

# %%
df4
# Out:
#    a
# 0  2
# 1  4
# 2  6
# 3  8

# %%
df4.rolling(window=1).mean()
# Out:
#      a
# 0  2.0
# 1  4.0
# 2  6.0
# 3  8.0

# %%
df4.rolling(window=2).mean()
# Out:
#      a
# 0  NaN
# 1  3.0
# 2  5.0
# 3  7.0

# %%
df4.rolling(window=3).mean()
# Out:
#      a
# 0  NaN
# 1  NaN
# 2  4.0
# 3  6.0

# %%
# Cumsum---------->cummalitve frequency
df4.cumsum()
# Out:
#     a
# 0   2
# 1   6
# 2  12
# 3  20

# %%
# Date function

# %%
date=pd.date_range(start="2023-04-23", end="2023-05-23")

# %%
date
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23'],
#               dtype='datetime64[ns]', freq='D')

# %%
d_date= pd.DataFrame({"Date": date})

# %%
d_date
# Out:
#          Date
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# 5  2023-04-28
# 6  2023-04-29
# 7  2023-04-30
# 8  2023-05-01
# 9  2023-05-02
# 10 2023-05-03
# 11 2023-05-04
# 12 2023-05-05
# 13 2023-05-06
# 14 2023-05-07
# 15 2023-05-08
# 16 2023-05-09
# 17 2023-05-10
# 18 2023-05-11
# 19 2023-05-12
# 20 2023-05-13
# 21 2023-05-14
# 22 2023-05-15
# 23 2023-05-16
# 24 2023-05-17
# 25 2023-05-18
# 26 2023-05-19
# 27 2023-05-20
# 28 2023-05-21
# 29 2023-05-22
# 30 2023-05-23

# %%
d_date.dtypes
# Out:
# Date    datetime64[ns]
# dtype: object

# %%
df5=pd.DataFrame({'Date': ["2023-05-19","2023-05-17","2023-05-14","2023-05-10"]})
df5
# Out:
#          Date
# 0  2023-05-19
# 1  2023-05-17
# 2  2023-05-14
# 3  2023-05-10

# %%
df5.dtypes
# Out:
# Date    object
# dtype: object

# %%
# to make this dates from object(string) to datetime
df5["update"] = pd.to_datetime(df5['Date'])
df5
# Out:
#          Date     update
# 0  2023-05-19 2023-05-19
# 1  2023-05-17 2023-05-17
# 2  2023-05-14 2023-05-14
# 3  2023-05-10 2023-05-10

# %%
df5.dtypes
# Out:
# Date              object
# update    datetime64[ns]
# dtype: object

# %%
#to separate date month col
df5["year"] = df5['update'].dt.year
df5["Month"] = df5['update'].dt.month
df5["date"] = df5['update'].dt.day

# %%
df5
# Out:
#          Date     update  year  Month  date
# 0  2023-05-19 2023-05-19  2023      5    19
# 1  2023-05-17 2023-05-17  2023      5    17
# 2  2023-05-14 2023-05-14  2023      5    14
# 3  2023-05-10 2023-05-10  2023      5    10

# %% [markdown]
# <!-- Time delta -->

# %%
# returns diff b/w two dates
td= pd.Timedelta(days=1)

dt=pd.to_datetime("2023-06-20")
td+dt
# Out:
# Timestamp('2023-06-21 00:00:00')

# %% [markdown]
# <!-- categorical data -->

# %%
data=["a",'b','c','a']

# %%
cat=pd.Categorical(data)
cat
# Out:
# ['a', 'b', 'c', 'a']
# Categories (3, object): ['a', 'b', 'c']

# %%
cat.value_counts()
# Out:
# a    2
# b    1
# c    1
# dtype: int64

# %% [markdown]
# <!-- visualization -->

# %%
d= pd.Series([24,4.6,88,23])
d
# Out:
# 0    24.0
# 1     4.6
# 2    88.0
# 3    23.0
# dtype: float64

# %%
d.plot()

# x-->index
# y-->val
# Out:
# <Axes: >

# %%
df= pd.DataFrame({'a':[3,4,5,6],
                 'b':[7,6,4,1],
                 })
df
# Out:
#    a  b
# 0  3  7
# 1  4  6
# 2  5  4
# 3  6  1

# %%
# to take one col as x and another as y
df.plot(x="a",y="b")
# Out:
# <Axes: xlabel='a'>

# %%
df.plot.scatter(x="a",y="b")
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
d.plot.pie()
# Out:
# <Axes: >

# %%
# for assignment

from datetime import datetime, timedelta
data = {
    'date': [],
    'product_category': [],
    'sales': []
}

start_date = datetime(2023, 1, 1)

for day in range(30):
    date = start_date + timedelta(days=day)
    for product_category in ['Category A', 'Category B', 'Category C']:
        data['date'].append(date)
        data['product_category'].append(product_category)
        data['sales'].append(day * 100 + 200 * (ord(product_category[-1]) - ord('A') + 1))

# Create a DataFrame from the data dictionary
df = pd.DataFrame(data)

# Convert the 'date' column to datetime
df['date'] = pd.to_datetime(df['date'])

# Save the DataFrame to a CSV file
csv_file_path = 'sales_data.csv'
df.to_csv(csv_file_path, index=False)
